# %%
# %matplotlib inline
from __future__ import print_function

from matplotlib import pyplot as plt
import seaborn as sns

import numpy as np
import pandas as pd

# %load_ext autoreload
# %autoreload 2

from utils.data_utils import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # micro

# %%
a,b,c = build_dataset(data,'micro')

# %%
data = load_raw_data()

# %%
def build_dataset(data,name):
    ''' build micro data 
    There is a gotcha here if we're not careful, which is that we are only using 
    microclimate data in this benchmark and ignoring the other available data—but
    the microclimate test data has some missing values!
    '''
    
    train = data['microclimat_train']
    train_y = data['labels']
    sub_format = data['submission_format']
    test = sub_format.join(data['microclimat_test'], how='left')
    test = test[microclimate_test.columns]
    
    return train, train_y, test

# %%
a,b,c,d = load_data()
# Out:
# Le train is composed by 19 group and 3354 observation
# Le val is composed by 7 group and 1083 observation
# Le test is composed by 8 group and 1361 observation

# %%
i= 0
for key,gp in d.df.groupby('group'):
    plt.scatter(gp.index,gp.temp,color = sns.color_palette('hls',len(d.df.groupby('group')))[i])
    i+=1

# %%
len(d.df)
# Out:
# 2314

# %%
sub_format = load_raw_data()['submission_format']
final_pred_format = sub_format.join(final_pred, how='left')
sub_format['yield'] = final_pred_format['yield_pred']
